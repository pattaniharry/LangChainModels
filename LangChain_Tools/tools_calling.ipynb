# %%
! pip install -q langchain-groq langchain-core requests
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 9.6 MB/s eta 0:00:00

# %%
import os
os.environ["GROQ_API_KEY"] = "gsk_0D1R6M5joJ8u8wkdkuvuWGdyb3FYx3SW9ObGhc"

# %%
from langchain_groq import ChatGroq
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
# tool creation

@tool
def multiply(a : int , b : int) -> int:
  """multiply 2 numbers given a and b  """
  return a * b

# %%
print(multiply.invoke({'a':4 , 'b':6}))
# Out:
# 24

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'multiply 2 numbers given a and b'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
# tool binding

# %%
llm = ChatGroq(
    model = "llama-3.1-8b-instant"
)

# %%
llm_with_multiply = llm.bind_tools(
    [
        multiply
    ]

)

# %%
#tool calling

result = llm_with_multiply.invoke("can you multiply 432 and 23")

# %%
result.tool_calls[0]['args']
# Out:
# {'a': 432, 'b': 23}

# %%
#tool execution

# %%
multiply.invoke(result.tool_calls[0])
# Out:
# ToolMessage(content='9936', name='multiply', tool_call_id='p2gyv214d')
